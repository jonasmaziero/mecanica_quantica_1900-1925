# %% [markdown]
# ### Estatística de notas versus número de faltas <br> Disciplina de Física Matemática II, UFSM

# %%
# %run init.ipynb
from scipy import optimize

# %%
def test_func(x, a, b):
    return a + b*x

# %%
faltas = np.array([8,4,6,12,23,4,11,2,2,14,12,12,6])
notas = np.array([7.77,5.1,7.52,5.52,0.96,9.16,3.82,7.99,8.46,5,8.52,4.17,5.02])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2014/2')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 8.74131105 -0.298509  ]

# %%
faltas = np.array([0,26,2,8,8,6,2,0,2,8,8,0,36])
notas = np.array([8.5,1.5,7.38,7.52,5.87,1.44,5,8.33,9.88,2.71,5.03,5.07,0.13])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2016/2')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 6.94224499 -0.20650174]

# %%
faltas = np.array([42,0,34,10,4,14,0,4,12,16,14,8,32,2,14])
notas = np.array([0,10,0.57,7.25,7.5,0,9.38,7.13,7.75,3.88,5.38,0.07,0,8.25,2.88])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2017/2')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 7.79238652 -0.22740679]

# %%
faltas = np.array([5,4,6,12,0,2,4,14,12,14,12])
notas = np.array([7.35,7.55,8.60,5,8.73,7.98,7.35,6.43,5,5,5])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('faltas')
plt.ylabel('notas')
plt.title('2018/2')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 8.70982106 -0.25668273]

# %%
faltas = np.array([2,15,14,15,10,6,22,10,8,12,2])
notas = np.array([10,6.32,8,6.32,7.25,8.07,0.57,1.75,8.63,6.38,10])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2019/2')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [10.62296503 -0.37553979]

# %%
faltas = np.array([8,4,6,12,23,4,11,2,2,14,12,12,6,2,15,14,15,10,6,22,10,8,12,2,5,4,6,12,0,2,4,14,12,14,12,42,0,34,10,4,14,0,4,12,16,14,8,32,2,14,0,26,2,8,8,6,2,0,2,8,8,0,36])
notas = np.array([7.77,5.1,7.52,5.52,0.96,9.16,3.82,7.99,8.46,5,8.52,4.17,5.02,10,6.32,8,6.32,7.25,8.07,0.57,1.75,8.63,6.38,10,7.35,7.55,8.60,5,8.73,7.98,7.35,6.43,5,5,5,0,10,0.57,7.25,7.5,0,9.38,7.13,7.75,3.88,5.38,0.07,0,8.25,2.88,8.5,1.5,7.38,7.52,5.87,1.44,5,8.33,9.88,2.71,5.03,5.07,0.13])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('Dados de 5 semestres')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 8.17432796 -0.23893905]

# %% [markdown]
# ### Estatística de notas versus número de faltas <br> Disciplina de Mecânica Quântica II, UFSM

# %%
faltas = np.array([16,0,16,34,8,10,14,14,2,12])
notas = np.array([0.7,7.07,0.57,0,5.1,4.57,0.71,5.95,3.56,7.4])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2017/1')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 6.02  -0.195]

# %%
faltas = np.array([0,2,4,5,11,2,15,14,1,13])
notas = np.array([10,6.48,7.94,7.29,1.34,8.8,7.24,1.83,5.37,8.69])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2018/1')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 7.98561038 -0.2220314 ]

# %%
faltas = np.array([4,12,14,19,13,10,6,15,26,8])
notas = np.array([5,6.32,8.5,0.13,5,3.38,5.82,3.5,0.13,1.25])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('2019/1')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 6.57712911 -0.21056135]

# %%
faltas = np.array([16,0,16,34,8,10,14,14,2,12,0,2,4,5,11,2,15,14,1,13,4,12,14,19,13,10,6,15,26,8])
notas = np.array([0.7,7.07,0.57,0,5.1,4.57,0.71,5.95,3.56,7.4,10,6.48,7.94,7.29,1.34,8.8,7.24,1.83,5.37,8.69,5,6.32,8.5,0.13,5,3.38,5.82,3.5,0.13,1.25])
params, params_covariance = optimize.curve_fit(test_func, faltas, notas, p0=[2, 2])
print(params)
plt.plot(faltas, test_func(faltas, params[0], params[1]), color = 'cyan',label='ajuste')
plt.scatter(faltas, notas, color = 'blue', label='dados')
plt.legend(loc='best')
plt.scatter(faltas, notas, color = 'blue')
plt.xlabel('Faltas')
plt.ylabel('Notas')
plt.title('Dados de 3 semestres')
axes = plt.gca()
axes.set_xlim([0,60])
axes.set_ylim([-1,11])
plt.show()
# Out:
# [ 7.2205     -0.24054687]
